# %%
from test import *
from concurrent.futures import ThreadPoolExecutor

# %%
url_no_page = 'https://ifsc.results.info/event/922/general/boulder&lead'
url_no_semifinal = 'https://ifsc.results.info/event/1377/general/boulder'
url_with_semifinal = 'https://ifsc.results.info/event/987/general/boulder'

urls = [url_with_semifinal, url_no_page, url_no_semifinal, url_with_semifinal, url_no_page, url_no_semifinal,url_with_semifinal,url_with_semifinal,url_with_semifinal,url_with_semifinal,url_with_semifinal,url_with_semifinal]
dfs = []
with ThreadPoolExecutor(max_workers=5) as executor:
    results = executor.map(scrape_one_url, urls)
final_df = pd.concat(results, ignore_index=True)
'''
for url in urls:
    df = scrape_one_url(url)
    if df is not None:
        dfs.append(df)
final_df = pd.concat(dfs, ignore_index=True)
'''
# Out:
# this modality doesnt exist for this event: https://ifsc.results.info/event/922/general/boulder&lead
# this modality doesnt exist for this event: https://ifsc.results.info/event/922/general/boulder&lead
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 urls = [url_with_semifinal, url_no_page, url_no_semifinal, url_with_semifinal, url_no_page, url_no_semifinal,url_with_semifinal,url_with_semifinal,url_with_semifinal,url_with_semifinal,url_with_semifinal,url_with_semifinal]
#       6 dfs = []
# ----> 7 with ThreadPoolExecutor(max_workers=5) as executor:
#       8     results = executor.map(scrape_one_url, urls)
#       9 final_df = pd.concat(results, ignore_index=True)
#
# File ~/anaconda3/lib/python3.11/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# ...

# %%
final_df.info()

# %%
final_df.tail()

# %%
final_df.info()
