# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('events_data.csv')

# %%
df.head()
# Out:
#    Year                               Event Title  \
# 0  1990                        Weltcup, Wien 1990
# 1  1990                  Weltcup, Open, Wien 1990
# 2  1990        Weltcup, Madonna di Campiglio 1990
# 3  1990  Weltcup, Open, Madonna di Campiglio 1990
# 4  1990                    Weltcup, Berkeley 1990
#
#                                   Href
# 0  https://ifsc.results.info/event/88/
# 1  https://ifsc.results.info/event/94/
# 2  https://ifsc.results.info/event/89/
# 3  https://ifsc.results.info/event/95/
# 4  https://ifsc.results.info/event/90/

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290 entries, 0 to 1289
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         1290 non-null   int64
#  1   Event Title  1290 non-null   object
#  2   Href         1290 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 30.4+ KB

# %%
df['Href_number'] = df['Href'].str.extract(r"(\d+)/?$")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290 entries, 0 to 1289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         1290 non-null   int64
#  1   Event Title  1290 non-null   object
#  2   Href         1290 non-null   object
#  3   Href_number  1290 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 40.4+ KB
